# %% [markdown]
# # Testing GRCWA vs TORCWA implementations of twobox

# %%
import matplotlib.pyplot as plt
import numpy as np

import sys
sys.path.append('../')

import torch
import time

import autolib 
import fom
from parameters import D1_ND, Parameters
from twobox import TwoBox
from ilic import *

npa = autolib.AutoLib('torch')
npaa = autolib.AutoLib('autograd')

# %%
print(torch.tensor([0j]))
# Out:
# tensor([0.+0.j])

# %% [markdown]
# ## Check getting and setting instance variables

# %% [markdown]
# ### Fixing a parameter in the middle of params

# %%
grating_fixed_gaussian = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG_torcwa, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=45,
                 fixed_parameters=["gaussian_width"])

assert grating_fixed_gaussian.gaussian_width == 20.
assert grating_fixed_gaussian.all_params == [grating_pitch, grating_depth, 
                                             box1_width, box2_width, box_centre_dist, 
                                             box1_eps, box2_eps, gaussian_width, 
                                             substrate_depth, substrate_eps]
assert grating_fixed_gaussian.params == [grating_pitch, grating_depth, 
                                             box1_width, box2_width, box_centre_dist, 
                                             box1_eps, box2_eps,
                                             substrate_depth, substrate_eps]
grating_fixed_gaussian.gaussian_width = 35.
assert grating_fixed_gaussian.gaussian_width == 35.
assert grating_fixed_gaussian.all_params == [grating_pitch, grating_depth, 
                                             box1_width, box2_width, box_centre_dist, 
                                             box1_eps, box2_eps, 35., 
                                             substrate_depth, substrate_eps]
assert grating_fixed_gaussian.params == [grating_pitch, grating_depth, 
                                             box1_width, box2_width, box_centre_dist, 
                                             box1_eps, box2_eps,
                                             substrate_depth, substrate_eps]

grating_fixed_gaussian.params = [2., 2., 0.1, 0.1, 0.2, 2., 2., 2., 2.]
assert grating_fixed_gaussian.all_params == [2., 2., 0.1, 0.1, 0.2, 2., 2., 35., 2., 2.]
assert grating_fixed_gaussian.params == [2., 2., 0.1, 0.1, 0.2, 2., 2., 2., 2.]

grating_fixed_gaussian.all_params = [4., 4., 0.2, 0.2, 0.4, 4., 4., 50., 4., 4.]
assert grating_fixed_gaussian.all_params == [4., 4., 0.2, 0.2, 0.4, 4., 4., 50., 4., 4.]
assert grating_fixed_gaussian.params == [4., 4., 0.2, 0.2, 0.4, 4., 4., 4., 4.]

# %% [markdown]
# ### Fixing multiple parameters

# %%
grating_fixed_params = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG_torcwa, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=45,
                 fixed_parameters=["gaussian_width", "substrate_eps"])
assert grating_fixed_params.gaussian_width == 20.
assert grating_fixed_params.substrate_eps == 2.1025
assert grating_fixed_params.all_params == [grating_pitch, grating_depth, 
                                             box1_width, box2_width, box_centre_dist, 
                                             box1_eps, box2_eps, gaussian_width, 
                                             substrate_depth, substrate_eps]
assert grating_fixed_params.params == [grating_pitch, grating_depth, 
                                             box1_width, box2_width, box_centre_dist, 
                                             box1_eps, box2_eps,
                                             substrate_depth]
grating_fixed_params.gaussian_width = 35.
grating_fixed_params.substrate_eps = -1e6
assert grating_fixed_params.gaussian_width == 35.
assert grating_fixed_params.substrate_eps == -1e6
assert grating_fixed_params.all_params == [grating_pitch, grating_depth, 
                                             box1_width, box2_width, box_centre_dist, 
                                             box1_eps, box2_eps, 35., 
                                             substrate_depth, -1e6]
assert grating_fixed_params.params == [grating_pitch, grating_depth, 
                                             box1_width, box2_width, box_centre_dist, 
                                             box1_eps, box2_eps,
                                             substrate_depth]

grating_fixed_params.params = [2., 2., 0.1, 0.1, 0.2, 2., 2., 2.]
assert grating_fixed_params.all_params == [2., 2., 0.1, 0.1, 0.2, 2., 2., 35., 2., -1e6]
assert grating_fixed_params.params == [2., 2., 0.1, 0.1, 0.2, 2., 2., 2.]

grating_fixed_params.all_params = [4., 4., 0.2, 0.2, 0.4, 4., 4., 50., 4., 4.]
assert grating_fixed_params.all_params == [4., 4., 0.2, 0.2, 0.4, 4., 4., 50., 4., 4.]
assert grating_fixed_params.params == [4., 4., 0.2, 0.2, 0.4, 4., 4., 4.]

# %% [markdown]
# ## Check FOM calculation

# %%
import fom
# Fdamp_all_params = [1.226     , 2.90479687, 0.31178695, 0.0071848 , 0.9995    , 2.96553672, 4.30675011, 25., 1., -1e6]
# Fdamp_grating = TwoBox(*Fdamp_all_params, wavelength=1., angle=0., Nx=100, nG=12, 
#                        Qabs=1e7, RCWA_engine='TORCWA',torcwa_edge_sharpness=45,
#                        fixed_parameters=["gaussian_width", "substrate_depth", "substrate_eps"])
# choose_monofom = fom.monofom_damp

# print(fom.multifom_uniform(Fdamp_grating, choose_monofom, 20., 0.1, return_grad=True))
# Fdamp_grating.show_spectrum(angle=0., efficiency_quantity="PDr", wavelength_range=[1,1.225], 
#                             num_plot_points=200, grad_method="grad")

p = 1.227
params = [1.227, 0.01*p, 0.01*p, 0.01*p , 0.03*p, 1.1**2, 1.1**2, 2., 0.01*p, 1.1**2]
grating = TwoBox(*params, wavelength=1., angle=0., Nx=100, nG=12, 
                       Qabs=1e7, RCWA_engine='TORCWA',torcwa_edge_sharpness=45)

print(fom.multifom_uniform(grating))
# Out:
# [np.float64(-2.315839721822356), array([ 3.86301919e+00, -7.37790506e+00, -1.91076989e-17, -1.91076997e-17,
#         6.13574388e-20, -2.16906487e-01, -2.16906509e-01,  1.11907993e-04,
#        -1.80868753e+02, -1.05894218e+01])]

# %% [markdown]
# ## Check analytic vs numerical eigenvalue calculation speed

# %%
import time
import random

runs = 1000
analytic_duration = 0.
numeric_duration = 0.
for i in range(runs):
    p = random.uniform(1.3,1.8)
    h = random.uniform(0.1,2.)
    w1 = random.uniform(0.05,0.5)
    w2 = random.uniform(0.05,0.5)
    bcd = random.uniform(0.1,0.5)
    e1 = random.uniform(1.1,3.5**2)
    e2 = random.uniform(1.1,3.5**2)
    gw = random.uniform(0.1, 50.)
    hs = random.uniform(0.1, 2.)
    es = random.uniform(1.1, 3.5**2)
    params = [p, h, w1, w2, bcd, e1, e2, gw, hs, es]
    grating = TwoBox(*params, wavelength=1., angle=0., Nx=100, nG=12, 
                    Qabs=1e7, RCWA_engine='TORCWA',torcwa_edge_sharpness=45)
    
    t0 = time.time()
    fom.Eigs(grating, grad_method="grad", use_perturbed=True)
    t1 = time.time()
    analytic_duration += t1 - t0

    t0 = time.time()
    fom.Eigs(grating, grad_method="grad", use_perturbed=False)
    t1 = time.time()
    numeric_duration += t1 - t0

analytic_avg = analytic_duration / runs
numeric_avg = numeric_duration / runs

print(analytic_avg)
print(numeric_avg)
print(100*(numeric_avg - analytic_avg)/numeric_avg)
# Out:
# 0.1409409875869751
# 0.14064015698432922
# -0.2139009292199521

# %% [markdown]
# # check show_eig

# %%
from ilic import *
gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG_torcwa, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=45)
gratingTorcwa.show_Eigs(wavelength_range=[1.0,1.5],num_plot_points=10)
gratingGRCWA = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG, Qabs, RCWA_engine='GRCWA')
gratingGRCWA.show_Eigs(wavelength_range=[1.0,1.5],num_plot_points=10)
# Out:
# c:\Users\Shaurya\miniforge3\envs\lightsail\Lib\site-packages\autograd\tracer.py:54: RuntimeWarning: invalid value encountered in arcsin
#   return f_raw(*args, **kwargs)
# (<Figure size 984.253x577.428 with 3 Axes>,
#  (<Axes: xlabel="$\\lambda'/\\Lambda'$", ylabel='$\\Re(\\lambda)$'>,
#   <Axes: xlabel="$\\lambda'/\\Lambda'$", ylabel='$\\Im(\\lambda)$'>))

# %% [markdown]
# # check show_depth_dependence

# %%
from ilic import *
gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG_torcwa, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=45)
gratingTorcwa.show_depth_dependence(angle=.1,efficiency_quantity='PDr',depth_range=[0,0.5],num_plot_points=50)
gratingGRCWA = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG, Qabs, RCWA_engine='GRCWA')
gratingGRCWA.show_depth_dependence(angle=.1,efficiency_quantity='PDr',depth_range=[0,0.5],num_plot_points=50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 5
#       1 from ilic import *
#       2 gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps,
#       3                  gaussian_width, substrate_depth, substrate_eps,
#       4                  wavelength, angle, Nx, numG_torcwa, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=45)
# ----> 5 gratingTorcwa.show_depth_dependence(angle=.1,efficiency_quantity='PDr',depth_range=[0,0.5],num_plot_points=50)
#       6 gratingGRCWA = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps,
#       7                  gaussian_width, substrate_depth, substrate_eps,
#       8                  wavelength, angle, Nx, numG, Qabs, RCWA_engine='GRCWA')
# ...

# %% [markdown]
# # Testing torch autograd

# %%
# %%script false --no-raise-error
# def f(x):
#     return (npa.sin(x[0])*x[1]**2)
# def fag(x):
#     return (npaa.sin(x[0])*x[1]**2)
# # g=npa.grad(f)
# print(autolib.grad_torch_value(f,npa.array([-1.0,4])),np.cos(-1.0),-1.0*4*2)
# print(npa.grad(f)(npa.array([-1.0,4]))[0].detach().numpy(),np.cos(-1.0),-1.0*4*2)
# print(npaa.grad(fag)(npaa.array([-1.0,4])),np.cos(-1.0),-1.0*4*2)
# # print(g(2.0))
# x=npa.array(3.0)
# #print(autolib.grad_torch_value(f,x))
# # print(f(x))
# # print(np.sin(x.detach().cpu().numpy()))
# y=3*x
# z=y**2
# print(torch.autograd.grad(z,x,create_graph=True))
# print(torch.autograd.grad(y,x))
# Out:
# Couldn't find program: 'false'

# %%
# %%script false --no-raise-error
# rotation_matrix_ag = npaa.array([[1.,-1.],[1.,1]])
# rotation_matrix_torcwa = npa.array([[1.,-1.],[1.,1.]])
# print('torcwa:', npa.eig(rotation_matrix_torcwa))
# print('autograd:',npaa.eig(rotation_matrix_ag))
# Out:
# Couldn't find program: 'false'

# %%
# %%script false --no-raise-error
# def f(x):
#     a=npaa.cos(x[0])
#     b=x[1]**2
#
#     return npaa.array([a,b])
# x=npaa.array([3.0,1.0])
# print(f(x))
# print(npaa.jacobian(f)(x))
# print('torch')
# def f(x):
#     a=npa.cos(x[0])
#     b=x[1]**2
#     return torch.stack((a,b))
# x=npa.array([3.0,1.0])
# print(f(x))
# print(npa.jacobian(f)(x))
# Out:
# Couldn't find program: 'false'

# %%
a = torch.tensor(1., requires_grad=True)
b = a**2
c = 5*b
c.backward()
print(a.grad)  # Prints: 10.
# Out:
# tensor(10.)

# %% [markdown]
# # Testing show_fields

# %%
 ## Ilic
wavelength      = 1.5 #/ D1_ND(1.2/100)
grating_pitch   = 1.8 / wavelength
grating_depth   = 0.5 / wavelength
box1_width      = 0.15 * grating_pitch
box2_width      = 0.35 * grating_pitch
box_centre_dist = 0.60 * grating_pitch
box1_eps        = 3.5**2 
box2_eps        = 3.5**2
gaussian_width  = 2* 10   # 2.7180049942915896 * 10
substrate_depth = 0.5 / wavelength
substrate_eps   = 1.45**2

wavelength      = 1.
angle           = 0.
Nx              = 300
numG            = 50
Qabs            = np.inf

gratingGRCWA = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG, Qabs, RCWA_engine='GRCWA')
numGTorcwa = int(numG/2)

heights=np.linspace(-2*grating_depth,4*grating_depth,50)
# heights=np.linspace(0,2*grating_depth,50)
_,axs=gratingGRCWA.show_fields(heights,field_output="abs",show_eps_profile=True)
axs.set_ylim((np.min(heights),np.max(heights)))
gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numGTorcwa, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=40)
gratingTorcwa.show_fields(heights,field_output="abs",show_eps_profile=True)
gratingTorcwa.substrate_eps = -1e6
gratingTorcwa.show_fields(heights,field_output="abs",show_eps_profile=True)
refl_Rs, refl_Ts = gratingTorcwa.eff()
print(refl_Rs, refl_Ts)
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# tensor([0.0282, 0.9527, 0.0192], dtype=torch.float64, grad_fn=<CopySlices>) tensor([0., 0., 0.], dtype=torch.float64, grad_fn=<CopySlices>)
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %% [markdown]
# # Testing second derivatives

# %%
wavelength      = 1.5 #/ D1_ND(1.2/100)
grating_pitch   = 1.8 / wavelength
grating_depth   = 0.5 / wavelength
box1_width      = 0.15 * grating_pitch
box2_width      = 0.35 * grating_pitch
box_centre_dist = 0.60 * grating_pitch
box1_eps        = 3.5**2 
box2_eps        = 3.5**2
gaussian_width  = 2* 10   # 2.7180049942915896 * 10
substrate_depth = 0.5 / wavelength
substrate_eps   = 1.45**2

wavelength      = 1.
angle           = 0.0
Qabs            = np.inf
numpoints=1
numG_torcwa=25
numG=2*numG_torcwa

Nx=300

eps=1e-4
gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG_torcwa, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=45)

def grad2_Q(grating, method_one, method_two, param_one, param_two, h_angle, h_wavelength):
    """
    TODO: update function documentation
    
    Parameters
    ----------
    method_one :   derivative method applied first - "grad" or "finite"
    method_two :   derivative method applied last - "grad" or "finite"
    param_one  :   variable for derivative method one - "angle" or "wavelength
    param_two  :   variable for derivative method two - "angle" or "wavelength
    h_angle    :   angular step size 
    h_angle    :   wavelength step size 
    
    Returns
    -------
    d^2 Q1/ d(), d^2 Q2/ d()
    NOTE: with TORCWA works with 'grad' automatic differentiation for both angle and wavelength 
            with GRCWA one of method_one, method_two must be 'finite' or code runs forever        
    """
    allowed_methods = ("grad", "finite")
    if (method_one or method_two) not in allowed_methods:
        invalid_quantity_message = f"Invalid derivative method. Allowed quantities are: {allowed_methods}"
        raise ValueError(invalid_quantity_message)
    allowed_variables = ("angle", "wavelength")
    if (param_one or param_two) not in allowed_variables:
        invalid_quantity_message = f"Invalid derivative method. Allowed quantities are: {allowed_variables}"
        raise ValueError(invalid_quantity_message)

    input_angle = grating.angle
    input_wavelength = grating.wavelength
    
    def restore():
        grating.angle = input_angle
        grating.wavelength = input_wavelength

    ## First call
    def first(angle, wavelength, method_one):
        
        if param_one == "angle":
            var = 0
            input = angle
            h = h_angle
            def backwards():
                grating.angle = input - h
                grating.wavelength = wavelength
            def forwards():
                grating.angle = input + h
                grating.wavelength = wavelength
        if param_one == "wavelength":
            var = 1
            input = wavelength
            h = h_wavelength
            def backwards():
                grating.angle = angle
                grating.wavelength = input - h
            def forwards():
                grating.angle = angle
                grating.wavelength = input + h
        
        if method_one=="finite":    
            
            ## Backwards
            backwards()
            Q_ = grating.Q()
            Q1_back = Q_[0]; Q2_back = Q_[1]

            ## Forwards
            forwards()
            Q_ = grating.Q()
            Q1_forwards = Q_[0]; Q2_forwards = Q_[1]

            ########### Derivatives
            PD_Q1 = (Q1_forwards - Q1_back) / (2 * h)
            PD_Q2 = (Q2_forwards - Q2_back) / (2 * h)

            grating.angle = angle
            grating.wavelength = wavelength

            if grating.RCWA_engine == 'TORCWA':
                return torch.stack((PD_Q1, PD_Q2))
            else:                    
                return grating.npa.array( [PD_Q1, PD_Q2] )

        if method_one=="grad":
            def Q_params(angle, wavelength):
                grating.angle = angle
                grating.wavelength = wavelength
                return grating.Q()
            

            PD = grating.npa.jacobian(Q_params, argnum = var)
            PD_value = PD(angle, wavelength)

            grating.angle = angle
            grating.wavelength = wavelength

            return PD_value

    ## Second call (+ composition)
    def second(method_two):
        if param_two == "angle":
            var = 0
            input = input_angle
            h = h_angle
            def backwards():
                angle = input - h
                wavelength = input_wavelength
                return angle, wavelength
            def forwards():
                angle = input + h
                wavelength = input_wavelength
                return angle, wavelength
        
        if param_two == "wavelength":
            var = 1
            input = input_wavelength
            h = h_wavelength
            def backwards():
                angle = input_angle
                wavelength = input - h
                return angle, wavelength
            def forwards():
                angle = input_angle
                wavelength = input + h
                return angle, wavelength

        if method_two == "finite":

            ## Backwards
            angle, wavelength = backwards()
            Q_ = first(angle, wavelength, method_one)
            Q1_back = Q_[0]; Q2_back = Q_[1]

            ## Forwards
            angle, wavelength = forwards()
            Q_ = first(angle, wavelength, method_one)
            Q1_forwards = Q_[0]; Q2_forwards = Q_[1]

            ########### Derivatives
            restore()
            PD_Q1 = (Q1_forwards - Q1_back) / (2 * h)
            PD_Q2 = (Q2_forwards - Q2_back) / (2 * h)

            if grating.RCWA_engine == 'TORCWA':
                return torch.stack((PD_Q1, PD_Q2))
            else:                    
                return grating.npa.array( [PD_Q1, PD_Q2] )
            

        if method_two == "grad":
            restore()

            def fun(angle, wavelength):
                return first(angle, wavelength, method_one)
            
            
            PD2 = grating.npa.jacobian(fun, argnum = var)
            PD2_value = PD2(input_angle, input_wavelength)
            restore()
            return PD2_value

    return second(method_two)

print('# *** torcwa:')
print('\n * angle/wavelength')
print('finite')
print(rf"$\partial_\theta\partial_{{\lambda}}$",grad2_Q(gratingTorcwa,'finite','finite','angle','wavelength',eps,eps))
print('grad/finite')
print(rf'$\partial_\theta\partial_{{\lambda}}$',grad2_Q(gratingTorcwa,'grad','finite','angle','wavelength',eps,eps))
print('finite/grad')
print(rf'$\partial_\theta\partial_{{\lambda}}$',grad2_Q(gratingTorcwa,'finite','grad','angle','wavelength',eps,eps))
print('grad/grad')
print(rf'$\partial_\theta\partial_{{\lambda}}$',grad2_Q(gratingTorcwa,'grad','grad','angle','wavelength',eps,eps))

print('\n* wavelength/wavelength')
print('finite')
print(rf"$\partial_\theta\partial_{{\lambda}}$",grad2_Q(gratingTorcwa,'finite','finite','wavelength','wavelength',eps,eps))
print('grad/finite')
print(rf'$\partial_\theta\partial_{{\lambda}}$',grad2_Q(gratingTorcwa,'grad','finite','wavelength','wavelength',eps,eps))
print('finite/grad')
print(rf'$\partial_\theta\partial_{{\lambda}}$',grad2_Q(gratingTorcwa,'finite','grad','wavelength','wavelength',eps,eps))
print('grad/grad')
print(rf'$\partial_\theta\partial_{{\lambda}}$',grad2_Q(gratingTorcwa,'grad','grad','wavelength','wavelength',eps,eps))

print('\n* angle/angle')
print('finite')
print(rf"$\partial_\theta\partial_{{\lambda}}$",grad2_Q(gratingTorcwa,'finite','finite','angle','angle',eps,eps))
print('grad/finite')
print(rf'$\partial_\theta\partial_{{\lambda}}$',grad2_Q(gratingTorcwa,'grad','finite','angle','angle',eps,eps))
print('finite/grad')
print(rf'$\partial_\theta\partial_{{\lambda}}$',grad2_Q(gratingTorcwa,'finite','grad','angle','angle',eps,eps))
print('grad/grad')
print(rf'$\partial_\theta\partial_{{\lambda}}$',grad2_Q(gratingTorcwa,'grad','grad','angle','angle',eps,eps))

print('\n* wavelength/angle')
print('finite')
print(rf"$\partial_\theta\partial_{{\lambda}}$",grad2_Q(gratingTorcwa,'finite','finite','wavelength','angle',eps,eps))
print('grad/finite')
print(rf'$\partial_\theta\partial_{{\lambda}}$',grad2_Q(gratingTorcwa,'grad','finite','wavelength','angle',eps,eps))
print('finite/grad')
print(rf'$\partial_\theta\partial_{{\lambda}}$',grad2_Q(gratingTorcwa,'finite','grad','wavelength','angle',eps,eps))
print('grad/grad')
print(rf'$\partial_\theta\partial_{{\lambda}}$',grad2_Q(gratingTorcwa,'grad','grad','wavelength','angle',eps,eps))

gratingGRCWA = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG, Qabs, RCWA_engine='GRCWA')
print('\n # *** grcwa ***')
print('finite')
print(rf'$\partial_\theta\partial_{{\lambda}}$',grad2_Q(gratingGRCWA,'finite','finite','angle','wavelength',eps,eps))
print('grad/finite')
print(rf'$\partial_\theta\partial_{{\lambda}}$',grad2_Q(gratingGRCWA,'grad','finite','angle','wavelength',eps,eps))
print('finite/grad')
print(rf'$\partial_\theta\partial_{{\lambda}}$',grad2_Q(gratingGRCWA,'finite','grad','angle','wavelength',eps,eps))
print('* wavelength/wavelength')
print('finite')
print(rf'$\partial_\theta\partial_{{\lambda}}$',grad2_Q(gratingGRCWA,'finite','grad','wavelength','wavelength',eps,eps))
print('* angle/angle')
print('finite')
print(rf'$\partial_\theta\partial_{{\lambda}}$',grad2_Q(gratingGRCWA,'finite','grad','angle','angle',eps,eps))
print('\n* wavelength/angle')
print('finite')
print(rf"$\partial_\theta\partial_{{\lambda}}$",grad2_Q(gratingGRCWA,'finite','finite','wavelength','angle',eps,eps))

# grad/grad for grwca runs for ever without result (?)
# print('grad/grad')
# print(rf'$\partial_\theta\partial_{{\lambda}}$',grad2_Q(gratingGRCWA,'grad','grad','angle','wavelength',eps,eps))
# Out:
# # *** torcwa:
#
#  * angle/wavelength
# finite
# $\partial_\theta\partial_{\lambda}$ tensor([  17.7514, -127.8025], device='cuda:0', dtype=torch.float64,
#        grad_fn=<StackBackward0>)
# grad/finite
# $\partial_\theta\partial_{\lambda}$ tensor([  17.7514, -127.8025], device='cuda:0', dtype=torch.float64,
#        grad_fn=<StackBackward0>)
# finite/grad
# $\partial_\theta\partial_{\lambda}$ tensor([  17.7604, -127.8042], device='cuda:0', dtype=torch.float64,
#        grad_fn=<ViewBackward0>)
# grad/grad
# $\partial_\theta\partial_{\lambda}$ tensor([  17.7605, -127.8042], device='cuda:0', dtype=torch.float64,
#        grad_fn=<ViewBackward0>)
#
# * wavelength/wavelength
# finite
# $\partial_\theta\partial_{\lambda}$ tensor([1492.2416,   28.6181], device='cuda:0', dtype=torch.float64,
#        grad_fn=<StackBackward0>)
# grad/finite
# $\partial_\theta\partial_{\lambda}$ tensor([1491.9231,   28.6933], device='cuda:0', dtype=torch.float64,
#        grad_fn=<StackBackward0>)
# ...

# %% [markdown]
# # Testing show spectrum method

# %%
wavelength      = 1.5 #/ D1_ND(1.2/100)
grating_pitch   = 1.8 / wavelength
# grating_pitch   = 2.5 / wavelength # original Ilic grating is 1.8, this is for testing over broader wl range

grating_depth   = 0.5 / wavelength
box1_width      = 0.15 * grating_pitch
box2_width      = 0.35 * grating_pitch
box_centre_dist = 0.60 * grating_pitch
box1_eps        = 3.5**2 
box2_eps        = 3.5**2
gaussian_width  = 2* 10   # 2.7180049942915896 * 10
substrate_depth = 0.5 / wavelength
substrate_eps   = 1.45**2

wavelength      = 1.
angle           = 0.0
Qabs            = np.inf
numpoints=1
numG_torcwa=25
numG=2*numG_torcwa

Nx=300

# %%
# %%script false --no-raise-error
# # check orders of grating
# gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps,
#                  gaussian_width, substrate_depth, substrate_eps,
#                  wavelength, angle, Nx, numG_torcwa, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=45)
# for wl in np.linspace(1.0,1.5,10):
#     print(f'{wl}: {gratingTorcwa.grating_orders(wavelength=wl)}')
# Out:
# Couldn't find program: 'false'

# %%
# %%script false --no-raise-error
# testing derivatives and jacobian
def rwlfun(wl):
    gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wl, angle, Nx, numG_torcwa, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=45)
    
    Rs,Ts=gratingTorcwa.eff()

    return Rs[1]

def rangfun(angle):
    wl=1.0
    gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wl, angle, Nx, numG_torcwa, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=45)
    
    Rs,Ts=gratingTorcwa.eff()

    return Rs[1]

gratingGRCWA = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG, Qabs, RCWA_engine='GRCWA')
print(gratingGRCWA.tNeg1(angle))
print((gratingGRCWA.tNeg1(angle+1e-6)-gratingGRCWA.tNeg1(angle-1e-6))/2e-6)
print(gratingGRCWA.PDtNeg1(angle))
print(gratingGRCWA.npa.jacobian(gratingGRCWA.tNeg1)(angle))

gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG_torcwa, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=45)
print('# torcwa')   
print(gratingTorcwa.tNeg1(gratingTorcwa.npa.array(angle)).item())
print(gratingTorcwa.PDtNeg1(gratingTorcwa.npa.array(angle))) #[0].detach().numpy() )
# gr=npa.grad(gratingTorcwa.rNeg1)
# angl=npa.array(0.4)
# print(gr(angl)[0].detach().numpy() )
# Out:
# 0.39635397698463176
# 1.9017317171299286
# 1.901731734732231
# 1.901731734732231
# # torcwa
# 0.39759464553270574
# tensor(1.9225, device='cuda:0', dtype=torch.float64, grad_fn=<ViewBackward0>)

# %%
# %%script false --no-raise-error
# # testing average_real_eigs - uses adaptive, not caomptible with torcwa
# # deprecated - removed.
# # use adaptive on the gradient for the figure of merit.
# wl=1.1
# gratingGRCWA = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps,
#                  gaussian_width, substrate_depth, substrate_eps,
#                  wavelength, angle, Nx, numG, Qabs, RCWA_engine='GRCWA')
# print('GRCWA:')
# print(gratingGRCWA.to_numpy(gratingGRCWA.average_real_eigs(0.05,20)))
#
# # torcwa
# gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps,
#                  gaussian_width, substrate_depth, substrate_eps,
#                  wavelength, angle, Nx, numG_torcwa, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=45)
# print('torcwa:')
# # gratingTorcwa.Linear_info(wl)
# print(gratingTorcwa.to_numpy(gratingTorcwa.average_real_eigs(0.05,20)))
# Out:
# Couldn't find program: 'false'

# %%
# %%script false --no-raise-error
# testing linear_info_new

wl=1.1
gratingGRCWA = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG, Qabs, RCWA_engine='GRCWA')
gratingGRCWA.wavelength = wl
print('GRCWA:')
print(gratingGRCWA.to_numpy(fom.lsa_info(gratingGRCWA)))
gratingGRCWA.wavelength = wavelength

# torcwa
gratingTorcwa.wavelength = wl
gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG_torcwa, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=45)
print('torcwa:')
# gratingTorcwa.Linear_info(wl)
print(gratingTorcwa.to_numpy(fom.lsa_info(gratingTorcwa)))
gratingTorcwa.wavelength = wavelength
# Out:
# GRCWA:
# ((np.float64(0.5794795498949169), np.float64(0.3730210557970982), np.float64(0.3028452851687631), np.float64(0.08670104376916143), np.float64(2.9040374051041162), np.float64(-5.631910702011661)), (np.float64(-48.204396988971084), np.float64(-457.61672651897686), np.float64(29.578321446400057), np.float64(-108.82326304546024)), (np.float64(-1.2287180118175223e-05), np.float64(0.0002992014208462547), np.float64(-3.802808247780609e-07), np.float64(3.465628315712003e-05)), array([-5.40975562, -5.40975562,  5.4097668 ,  5.4097668 ]), array([ 10.38170013, -10.38170013,  10.3816663 , -10.3816663 ]), array([[-0.03811841-0.07315191j, -0.03811841+0.07315191j,
#          0.03811864-0.07315195j,  0.03811864+0.07315195j],
#        [ 0.01543087-0.0142014j ,  0.01543087+0.0142014j ,
#         -0.01543089-0.01420163j, -0.01543089+0.01420163j],
#        [ 0.96565246+0.j        ,  0.96565246-0.j        ,
#          0.96565209+0.j        ,  0.96565209-0.j        ],
# ...

# %%
# %%script false --no-raise-error
# # FoM - not working - deprecated.
# numpoints=20
# wavelength_range=[1.0,1.15]
#
# start_time=time.time()
# gratingGRCWA = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps,
#                  gaussian_width, substrate_depth, substrate_eps,
#                  wavelength, angle, Nx, numG, Qabs, RCWA_engine='GRCWA')
# print('finite')
# plotbox.show_spectrum(gratingGRCWA, wavelength_range=wavelength_range, num_plot_points=numpoints, grad_method='finite')
# print('grad')
# plotbox.show_spectrum(gratingGRCWA, wavelength_range=wavelength_range, num_plot_points=numpoints, grad_method='grad')
# print('GRCWA time = ',time.time()-start_time)
#
#
# # torcwa
# gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps,
#                  gaussian_width, substrate_depth, substrate_eps,
#                  wavelength, angle, Nx, numG_torcwa, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=45)
# start_time=time.time()
# print('finite')
# plotbox.show_spectrum(gratingTorcwa, wavelength_range=wavelength_range, num_plot_points=numpoints, grad_method='finite')
# print('grad')
# plotbox.show_spectrum(gratingTorcwa, wavelength_range=wavelength_range, num_plot_points=numpoints, grad_method='grad')
# print('Torcwa time = ',time.time()-start_time)
# Out:
# Couldn't find program: 'false'

# %%
# %%script false --no-raise-error
# # eigenvalues using show spectrum: deprecated
# numpoints=20
# wavelength_range=[1.0,1.15]
# gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps,
#                  gaussian_width, substrate_depth, substrate_eps,
#                  wavelength, angle, Nx, numG_torcwa, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=45)
# start_time=time.time()
# print('finite')
# # gratingTorcwa.show_spectrum(efficiency_quantity='eig',num_plot_points=numpoints, grad_method='finite',wavelength_range=wavelength_range)
# print('grad')
# gratingTorcwa.show_spectrum(efficiency_quantity='eig',num_plot_points=numpoints, grad_method='grad',wavelength_range=wavelength_range)
# print('Torcwa time = ',time.time()-start_time)
# start_time=time.time()
# gratingGRCWA = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps,
#                  gaussian_width, substrate_depth, substrate_eps,
#                  wavelength, angle, Nx, numG, Qabs, RCWA_engine='GRCWA')
# print('finite')
# gratingGRCWA.show_spectrum(efficiency_quantity='eig',num_plot_points=numpoints,grad_method='finite',wavelength_range=wavelength_range)
# print('grad')
# gratingGRCWA.show_spectrum(efficiency_quantity='eig',num_plot_points=numpoints,grad_method='grad',wavelength_range=wavelength_range)
# print('GRCWA time = ',time.time()-start_time)
# Out:
# Couldn't find program: 'false'

# %%
wavelength_range=np.array([1.01,1.25])
# derivatives vs angle
gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG_torcwa, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=45)
start_time=time.time()
# gratingTorcwa.show_spectrum(efficiency_quantity='eig',num_plot_points=numpoints)
gratingTorcwa.show_spectrum(efficiency_quantity='PDt',num_plot_points=100,wavelength_range=wavelength_range)
print('Torcwa time = ',time.time()-start_time)

start_time=time.time()
gratingGRCWA = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG, Qabs, RCWA_engine='GRCWA')
# gratingGRCWA.show_spectrum(efficiency_quantity='eig',num_plot_points=numpoints)
gratingGRCWA.show_spectrum(efficiency_quantity='PDt',num_plot_points=100,wavelength_range=wavelength_range)
print('GRCWA time = ',time.time()-start_time)
# Out:
# z:\Github\relativistic-lightsail-dynamics\plotbox.py:322: RuntimeWarning: invalid value encountered in sqrt
#   diffraction_trig[3,idx] = diffraction_trig[5,idx] = np.sqrt(1 - sm**2)
# Torcwa time =  31.568028688430786
# GRCWA time =  37.1788649559021

# %% [markdown]
# ### Observing single-grating diffraction symmetries (possibly reciprocity)

# %%
gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, -1e6,
                 wavelength, angle, Nx, numG_torcwa, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=45)
gratingTorcwa.show_spectrum(angle=0., efficiency_quantity="r", wavelength_range=[1.,1.2], num_plot_points=200, grad_method='grad')

# gratingTorcwa.show_angular_efficiency(theta_max=20., num_plot_points=200)

# %% [markdown]
# # Ilic grating

# %%
 ## Ilic
wavelength      = 1.5 #/ D1_ND(1.2/100)
grating_pitch   = 1.8 / wavelength
grating_depth   = 0.5 / wavelength
box1_width      = 0.15 * grating_pitch
box2_width      = 0.35 * grating_pitch
box_centre_dist = 0.60 * grating_pitch
box1_eps        = 3.5**2 
box2_eps        = 3.5**2
gaussian_width  = 2* 10   # 2.7180049942915896 * 10
substrate_depth = 0.5 / wavelength
substrate_eps   = 1.45**2

wavelength      = 1.
angle           = 0.
Nx              = 300
numG            = 12
Qabs            = np.inf

gratingGRCWA = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG, Qabs, RCWA_engine='GRCWA')
numGTorcwa = numG
gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numGTorcwa, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=40)

# %% [markdown]
# ### plot epsilon

# %%
gratingGRCWA.show_permittivity(show_analytic_box=True)
gratingTorcwa.show_permittivity(show_analytic_box=True)

# %% [markdown]
# Edge effect vs edge sharpness parameter in torcwa

# %%
for sharp in np.array([1,10,100,1000]):
    gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=sharp)
    print('sharpness = ',sharp)
    gratingTorcwa.show_permittivity(show_analytic_box=True)

# %% [markdown]
# ## Fourier truncation effect in Torcwa
# It seems much better at avoiding Gibbs phenomena than gRCWA, even with sharpness of 1000, surprising.

# %%
for order in np.array([3,10,25]):
    gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, order, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=100)
    print('order = ',order)
    gratingTorcwa.show_permittivity(show_analytic_box=True)

# %% [markdown]
# # R, T vs angle for Ilic

# %%
from twobox import TwoBox
from ilic import *
numG=50
Nx=100
import time
start = time.time()
gratingGRCWA = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG, Qabs, RCWA_engine='GRCWA')
gratingGRCWA.show_angular_efficiency()
print('GRCWA time = ',time.time()-start)
start = time.time()
numG=25
gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                 gaussian_width, substrate_depth, substrate_eps,
                 wavelength, angle, Nx, numG, Qabs, RCWA_engine='TORCWA', torcwa_edge_sharpness=50)

gratingTorcwa.show_angular_efficiency()
print('TORCWA time = ',time.time()-start)

# %% [markdown]
# # Convergence test and timing TORCWA vs GRCWA

# %%
Nx=600
import time
start = time.time()
rGRCWA=[]
rTorcwa=[]
numRange=np.array(range(10,100,5))
# numRange=np.array(range(20,30,1))
plt.figure()
for lnumG in numRange:
    tempstart = time.time()
    gratingGRCWA = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                    gaussian_width, substrate_depth, substrate_eps,
                    wavelength, angle, Nx, int(lnumG), Qabs, RCWA_engine='GRCWA')
    print('time = ',time.time()-tempstart)
    Rs,Ts=gratingGRCWA.eff()    
    rGRCWA.append(Rs[1])
    
    x0,eps_array=gratingGRCWA.return_epsilon()
    
    plt.plot(x0,np.real(eps_array),label=f'nG={lnumG}')

print('GRCWA time = ',time.time()-start)
plt.legend()
plt.title('gRCWA')

plt.ylabel('Re(eps)')
plt.xlabel('x')

plt.figure()
start = time.time()
for lnumG in numRange:
    tempstart = time.time()
    gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                    gaussian_width, substrate_depth, substrate_eps,
                    wavelength, angle, Nx, lnumG, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=45)
    print('time = ',time.time()-tempstart)
    Rs,Ts=gratingTorcwa.eff()    
    rTorcwa.append(Rs[1].detach().cpu().numpy())
    x0,eps_array=gratingTorcwa.return_epsilon()
    plt.plot(x0,np.real(eps_array),label=f'nG={lnumG}')


print('TORCWA time = ',time.time()-start)
plt.title('Torcwa')
plt.ylabel('Re(eps)')
plt.xlabel('x')
plt.legend()

# %%
plt.figure()
fig,axs=plt.subplots(2,2)

axs[0,0].semilogy(numRange[0:-2],abs(np.array(rGRCWA[0:-2])-rGRCWA[-1]),label='GRCWA')
axs[0,0].semilogy(numRange[0:-2],abs(np.array(rTorcwa[0:-2])-rTorcwa[-1]),label='TORCWA')
axs[0,0].legend()
axs[0,0].set(xlabel='nG=order')
axs[0,0].set(ylabel='abs(r(order)-r(final))')


axs[1,0].plot(numRange,np.real(rGRCWA),label='gRCWA')
axs[1,0].plot(numRange,np.real(rTorcwa),label='Torcwa')
axs[1,0].legend()
axs[1,0].set(ylabel='Re(r)')
axs[1,0].set(xlabel='nG=order')

axs[0,1].semilogy(numRange[0:-2],abs(np.array(rGRCWA[0:-2])-rGRCWA[-1]),label='GRCWA')
axs[0,1].semilogy(2*numRange[0:-2]+1,abs(np.array(rTorcwa[0:-2])-rTorcwa[-1]),label='TORCWA')
axs[0,1].legend()
axs[0,1].set(xlabel='2*order+1,nG')
axs[0,1].set(ylabel='abs(r(order)-r(final))')


axs[1,1].plot(numRange,np.real(rGRCWA),label='gRCWA')
axs[1,1].plot(2*numRange+1,np.real(rTorcwa),label='Torcwa')
axs[1,1].legend()
axs[1,1].set(ylabel='Re(r)')
axs[1,1].set(xlabel='2order+1,nG')
# fig.suptitle('RCWA vs TROCWA convergence, using float64/complex128 ')
fig.suptitle('RCWA vs TROCWA convergence, using float32/complex64 ')

# %%
Nx=600
import time
numG=100
rGRCWA=[]
rTorcwa=[]
tTorcwa=[]
sharpnessRange=np.array(range(30,60,1))
# plt.figure()
gratingGRCWA = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                gaussian_width, substrate_depth, substrate_eps,
                wavelength, angle, Nx, int(numG), Qabs, RCWA_engine='GRCWA')
Rs,Ts=gratingGRCWA.eff()
rGRCWA=Rs
tGRCWA=Ts
numG=50


# plt.figure()
for sharpness in sharpnessRange:
    gratingTorcwa = TwoBox(grating_pitch, grating_depth, box1_width, box2_width, box_centre_dist, box1_eps, box2_eps, 
                    gaussian_width, substrate_depth, substrate_eps,
                    wavelength, angle, Nx, numG, Qabs, RCWA_engine='TORCWA',torcwa_edge_sharpness=sharpness)
    Rs,Ts=gratingTorcwa.eff()    
    rTorcwa.append(Rs.detach().cpu().numpy())
    tTorcwa.append(Ts.detach().cpu().numpy())

rTorcwa=np.array(rTorcwa)
tTorcwa=np.array(tTorcwa)

# %%
orders=[-1,0,1]
for j in range(len(rGRCWA)):
    plt.plot(sharpnessRange,(rTorcwa[:,j]-rGRCWA[j]),label=rf'$r_{orders[j]}$')
    plt.plot(sharpnessRange,(tTorcwa[:,j]-tGRCWA[j]),label=rf'$t_{orders[j]}$')
plt.axhline(ls=':',c='k')
plt.title(r'Torcwa for different values of sharpness vs GRCWA ')
plt.ylabel(r'$R_{Torcwa}-R_{gRCWA}, T_{Torcwa}-T_{gRCWA}$')
plt.xlabel('sharpness')
plt.legend()
